# %%
import report_tools
import json

# %%
paths_dict = {"root": '/data/eeg/scalp/ltp/presrate_MTurk', "event": '/data/eeg/scalp/ltp/presrate_MTurk/events', "data": '/data/eeg/scalp/ltp/presrate_MTurk/data'}

# %%
bad_subs = report_tools.get_bad_subs(paths_dict)

# %%
cleaned_events = report_tools.load_clean_events(paths_dict)

# %%
all_events = report_tools.load_all_events(paths_dict)

# %%
cleaned_data = report_tools.load_clean_data(paths_dict)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-46e7f1080620> in <module>
# ----> 1 cleaned_data = report_tools.load_clean_data(paths_dict)
#
# ~/MTurk_Experiments/scripts/post_process/report_tools.py in load_clean_data(paths_dict)
#      25     files = [f for f in files if os.path.basename(f).split('.')[0] not in bad_subs]
#      26
# ---> 27     return _read_saved_dataframes(files)
#      28
#      29 def load_all_data(paths_dict):
#
# ~/MTurk_Experiments/scripts/post_process/report_tools.py in _read_saved_dataframes(files)
#      39         all_data.append(pd.read_json(f))
#      40
# ---> 41     return pd.concat(all_data)
#      42
#      43 def get_bad_subs(paths_dict):
#
# ~/.conda/envs/cml/lib/python3.7/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
# ...

# %%
all_data = report_tools.load_all_data(paths_dict)

# %%
all_events

# %%
from glob import glob
#print(glob('/data/eeg/scalp/ltp/serialrec_MTurk/events/*.json'))
files = glob('/home1/connor.keane/temp/debug.json')
with open(files[0], 'r') as f:
    data = json.load(f)
    
#print(data.keys())
#print(data["data"])
#times = np.asarray([d.get("dateTime", -1) for d in data["data"]])
def sort_func(d):
    if d["trialdata"].get("type", None) == "WORD":
        return True

rec_evs = [d for d in data["data"] if sort_func(d)]
#print(times[1:] - times[:-1])

# %%
rec_evs
# Out:
# [{'current_trial': 86,
#   'trialdata': {'trial_type': 'positional-html-display',
#    'time_elapsed': 475310,
#    'length': 16,
#    'condition': -1,
#    'internal_node_id': '0.0-17.0-0.0',
#    'type': 'WORD',
#    'trial_index': 86},
#   'uniqueid': 'debug8UWNLY:debugAZ9DI2',
#   'dateTime': 1587416437981},
#  {'current_trial': 87,
#   'trialdata': {'trial_type': 'positional-html-display',
#    'time_elapsed': 477373,
#    'length': 16,
#    'condition': -1,
#    'internal_node_id': '0.0-17.0-1.0',
#    'type': 'WORD',
#    'trial_index': 87},
#   'uniqueid': 'debug8UWNLY:debugAZ9DI2',
#   'dateTime': 1587416440044},
#  {'current_trial': 88,
#   'trialdata': {'trial_type': 'positional-html-display',
#    'time_elapsed': 479510,
#    'length': 16,
#    'condition': -1,
#    'internal_node_id': '0.0-17.0-2.0',
#    'type': 'WORD',
#    'trial_index': 88},
#   'uniqueid': 'debug8UWNLY:debugAZ9DI2',
#   'dateTime': 1587416442181},
#  {'current_trial': 89,
# ...

# %%
import pandas as pd
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

df = pd.read_json('/data/eeg/scalp/ltp/serialrec_MTurk/data/MTK0025.json')
df
# Out:
#      index  condition  counterbalance  interval  intrusion        item  \
# 0        0          0               0       NaN        NaN      DONKEY
# 1        1          0               0       NaN        NaN      STAPLE
# 2        2          0               0       NaN        NaN        FILM
# 3        3          0               0       NaN        NaN      COURSE
# 4        4          0               0       NaN        NaN      GUITAR
# 5        5          0               0       NaN        NaN         LEG
# 6        6          0               0       NaN        NaN      THREAD
# 7        7          0               0       NaN        NaN       EGYPT
# 8        8          0               0       NaN        NaN       MAPLE
# 9        9          0               0       NaN        NaN        CRAB
# 10      10          0               0       NaN        NaN     HANDBAG
# 11      11          0               0       NaN        NaN      ORCHID
# ...

# %%
df.loc[df["type"] == 'WORD', "serialpos"] = df.loc[df["type"] == 'WORD', "serialpos"].apply(lambda x: x -1)
df
# Out:
#      index  condition  counterbalance  interval  intrusion        item  \
# 0        0          0               0       NaN        NaN      DONKEY
# 1        1          0               0       NaN        NaN      STAPLE
# 2        2          0               0       NaN        NaN        FILM
# 3        3          0               0       NaN        NaN      COURSE
# 4        4          0               0       NaN        NaN      GUITAR
# 5        5          0               0       NaN        NaN         LEG
# 6        6          0               0       NaN        NaN      THREAD
# 7        7          0               0       NaN        NaN       EGYPT
# 8        8          0               0       NaN        NaN       MAPLE
# 9        9          0               0       NaN        NaN        CRAB
# 10      10          0               0       NaN        NaN     HANDBAG
# 11      11          0               0       NaN        NaN      ORCHID
# ...

# %%
import numpy as np
print(list(zip(*[("type",  str), ("list", np.int16),
                            ("itemno", np.int16), ("item", str),
                            ("mstime", np.float), ("rectime", np.float)])))
# Out:
# [('type', 'list', 'itemno', 'item', 'mstime', 'rectime'), (<class 'str'>, <class 'numpy.int16'>, <class 'numpy.int16'>, <class 'str'>, <class 'float'>, <class 'float'>)]

# %%
def change_dict(val):
    b = val
    b["one"] = 2

a = {"one": 1}
change_dict(a)
a
# Out:
# {'one': 2}

# %%
import pandas as pd
s = pd.Series([1, 2, 3, 4, 5])
df = pd.DataFrame({"A": s, "B": s ** 2, "list": [1, 1, 2, 2, 3]})
df
# Out:
#    A   B  list
# 0  1   1     1
# 1  2   4     1
# 2  3   9     2
# 3  4  16     2
# 4  5  25     3

# %%
df.groupby("list").apply(np.array)
# Out:
# list
# 1     [[1, 1, 1], [2, 4, 1]]
# 2    [[3, 9, 2], [4, 16, 2]]
# 3               [[5, 25, 3]]
# dtype: object

# %%
df.groupby("list")

# %%
a = np.array([[1, 2, 3, 0, 0],
              [4, 5, 8, 6, 1]])

b = np.array([[2, 1, 3, 0, 0],
              [6, 5, 4, 8, 1]])

# -3, 0, 2, 1, 0

# %%
np.argwhere(a == b)
# Out:
# array([[0, 2],
#        [0, 3],
#        [0, 4],
#        [1, 1],
#        [1, 4]])

# %%
a_ind = np.argsort(a)

# %%
b_ind = np.argsort(b)

# %%
serial = np.arange(0, a.shape[1])

# %%
np.argsort(a[1][a_ind[1]][b_ind[1]]) - a_ind[1]
# Out:
# array([-1,  2,  0,  1, -2])

# %%
a_ind[1][serial]
# Out:
# array([4, 0, 1, 3, 2])

# %%
(b_ind[1] -  serial) + (a_ind[1] - serial)
# Out:
# array([ 8,  0, -2, -3, -3])

# %%
indices = np.where(np.in1d(b[1], a[1]))[0]

# %%
indices
# Out:
# array([0, 1, 2, 3, 4])

# %%
np.in1d(b[1], a[1])
# Out:
# array([ True,  True,  True,  True,  True])

# %%
xsorted = np.argsort(a)
ypos = np.searchsorted(a[xsorted], b)
indices = xsorted[ypos]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-229-ceb37b0f1edb> in <module>
#       1 xsorted = np.argsort(a)
# ----> 2 ypos = np.searchsorted(a[xsorted], b)
#       3 indices = xsorted[ypos]
#
# IndexError: index 3 is out of bounds for axis 0 with size 2

# %%
xsorted
# Out:
# array([[3, 4, 0, 1, 2],
#        [4, 0, 1, 3, 2]])

# %%
indices - serial
# Out:
# array([ 3,  0, -2, -1,  0])

# %%
serial-indices
# Out:
# array([-3,  0,  2,  1,  0])

# %%
pd.read_json('/home1/connor.keane/temp/test_data/data/debug.json').to_csv("/home1/connor.keane/temp/HK_test.csv")

# %%
import matplotlib.pyplot as plt
import numpy as np
data = np.random.random((40,))

# %%
plt.hist(data, density=True)
# Out:
# (array([1.02321112, 0.76740834, 1.02321112, 0.51160556, 1.02321112,
#         0.76740834, 1.53481668, 1.2790139 , 1.02321112, 1.2790139 ]),
#  array([0.01030368, 0.10803522, 0.20576676, 0.30349831, 0.40122985,
#         0.49896139, 0.59669293, 0.69442447, 0.79215601, 0.88988755,
#         0.98761909]),
#  <a list of 10 Patch objects>)

# %%
lists_0 = [['FOOT', 'SPEED', 'BLADE', 'TUMBLR',             'MUNCH', 'PIE', 'HEADPHONE', 'SPHINX', 'PUPPY', 'STOMACH', 'BLANKET', 'DROWSE', 'SURVEY', 'TABLET', 'PLAY', 'CHEMIST',        'GIGGLE', 'MASK', 'PIGEON', 'FEMALE', 'COKE', 'WHISKERS', 'BRANDY', 'WAITER'], ['COOKIE', 'DRINK', 'STEAK', 'SPOOL',          'PARTNER', 'ROBIN', 'SNACK', 'CATCHER', 'OUTFIT', 'COFFEE', 'TELEVISION', 'ATM', 'SING', 'GYMNAST', 'TEACHER', 'BLOUSE',      'XEROX', 'GUM', 'NAPKIN', 'INFANT', 'CACKLE', 'JOKE', 'WRENCH', 'NETFLIX'], ['GAMECUBE', 'FILM', 'GRATIFY', 'GHETTO',         'SUSHI', 'FROLIC', 'INSTAGRAM', 'VAGRANT', 'FLAG', 'NEUTRON', 'SLIDE', 'JUGGLER', 'FACEBOOK', 'LAMP', 'CHAUFFEUR',            'DUSTPAN', 'CANDY', 'SMILE', 'LAGOON', 'NAP', 'CIGAR', 'RABBIT', 'PERFUME', 'CANOE'], ['SHORTCAKE', 'NOVEL', 'BLUNT',         'COBRA', 'BUY', 'MOVIE', 'COMPLEMENT', 'PIZZA', 'TRACTOR', 'TRANSPLANT', 'SEAL', 'BREATHE', 'MAPLE', 'WATER', 'GUITAR',       'POPCORN', 'POET', 'SPEND', 'CIDER', 'ICEBERG', 'ANKLE', 'ACTRESS', 'VODKA', 'DANCE'], ['FARMER', 'CYCLONE', 'PEDICURE',      'BARLEY', 'PARTY', 'TWITTER', 'NACHOS', 'FIREPLACE', 'SPOON', 'ZEBRA', 'XBOX', 'PEPPER', 'CHICKEN', 'BROWNIE', 'SEAGULL',     'COUSIN', 'CHOCOLATE', 'POPSICLE', 'VALVE', 'SKYDIVE', 'KISS', 'CAPTIVE', 'SUITCASE', 'DONUT'], ['FOX', 'BUGGY', 'BABY',      'SAVOR', 'HEART', 'HANDBAG', 'JAPAN', 'LEMONADE', 'TROUT', 'PECAN', 'PILLOW', 'MARGARITA', 'MUSIC', 'PALACE', 'COSTUME',      'HEDGE', 'MEME', 'JUMP', 'FRIES', 'LUMBER', 'ICE CREAM', 'WINE', 'CHUCKLE', 'LAUGH'], ['YOUTUBE', 'SPOUSE', 'PEPSI',          'WHISKY', 'GRAVE', 'SEX', 'MCDONALD’S', 'CRAYON', 'BLACKJACK', 'LODGE', 'PLIERS', 'CRUNCH', 'BURGER', 'NURSE',                'CONVERSE', 'MISSILE', 'GALLON', 'UNWIND', 'EMPIRE', 'TUNNEL', 'STAMP', 'RELAX', 'REST', 'CHEST'], ['POCKET', 'TETRIS',       'CAT', 'COMPUTER', 'MINDFULNESS', 'CROSS', 'RECORD', 'LUNCH', 'COUCH', 'EGGS', 'FRUIT', 'OUTDOORS', 'SALMON', 'BURGER         KING', 'BATHTUB', 'COMFORTER', 'STUDENT', 'PRINCESS', 'SHOWER', 'BANJO', 'JACUZZI', 'WENDY’S', 'MARSHMALLOW', 'WAGON'],       ['BLUEPRINT', 'ATOM', 'KLEENEX', 'BEER', 'FINGER', 'MINECRAFT', 'PHONE', 'LOVER', 'CIGARETTE', 'ENTERTAIN', 'SHOES',          'VENUS', 'SPLURGE', 'SHRUB', 'CREVICE', 'MUSTARD', 'SNAKE', 'REPORT', 'BRACES', 'GAMBLE', 'MANICURE', 'POKER', 'CAKE',        'EAT'], ['PACKAGE', 'PADDLE', 'RUM', 'INTERNET', 'COOK', 'LABEL', 'NEWSPAPER', 'HERO', 'COWBOY', 'FOREST', 'TREAT',           'TYPIST', 'MASSAGE', 'LADY', 'BOOGIE', 'LAVA', 'SMOKE', 'SNOOZE', 'CUPCAKE', 'SHORTS', 'STROLL', 'SIBLING', 'SCRIBBLE',       'ONLINE']]

# %%
lists_1 = [['PARSLEY', 'WORKER', 'RIFLE', 'QUARTER',        'TURTLE', 'INVEST', 'MARATHON', 'TWISTER', 'KETCHUP', 'DIET', 'ELLIPTICAL', 'BLOOD PRESSURE', 'MENTAL HEALTH', 'HUSBAND',     'CROWN', 'HOUSE', 'MARKER', 'UPGRADE', 'GOBLIN', 'PROMISE', 'FREEZER', 'BLENDER', 'WORK', 'DEFER'], ['RUG', 'MOTEL',          'BODYBUILDER', 'BEAST', 'CLAMP', 'BADGE', 'VACCINE', 'DUMBBELL', 'CLASSIFY', 'MARRIAGE', 'SCHEDULE', 'CATEGORIZE',            'TRUCK', 'BOUQUET', 'DIME', 'RETIRE', 'DASHBOARD', 'UMPIRE', 'PROTON', 'SILK', 'EDUCATION', 'CALCIUM', 'RECOVERY',            'STUDY'], ['CHILDREN', 'JOB', 'CREDIT', 'SWORD', 'FAMILY', 'CLIMBER', 'HOLIDAY', 'BURGLAR', 'STAR', 'DATE', 'ASSEMBLE',       'SCALPEL', 'EXPERT', 'UNIVERSITY', 'SCULPTURE', 'CURTAIN', 'SCHOOL', 'LACE', 'TAXI', 'DOLPHIN', 'BUREAU', 'STONE',            'MONEY', 'RELATIONSHIP'], ['BOND', 'PROFIT', 'BISON', 'FORGIVE', 'SALAD', 'DRAGON', 'JOG', 'DISCOVERY', 'LONDON',             'NEGOTIATE', 'EXAM', 'KIDNEY', 'BASEMENT', 'IGLOO', 'WORLD', 'LIBRARY', 'CAREER', 'YOGA', 'PATROL', 'POSTAGE', 'LOVE',        'GRANDCHILDREN', 'KEEPER', 'NIGHTGOWN'], ['WASP', 'CAMEL', 'SHERIFF', 'DIABETES', 'WEEKEND', 'RAISE', 'LOAN', 'LAKE',         'DRIVER', 'ESSAY', 'MEDICINE', 'AGE', 'PAINTING', 'SAUSAGE', 'PIANO', 'FLIPPER', 'FINANCE', 'BANK', 'SWAMP', 'MORTGAGE',      'HARP', 'VIKING', 'ISLAND', 'SAVE'], ['SHIRT', 'RISK', 'SUPPORT', 'COUNTRY', 'SISTER', 'BUDGET', 'TAXES', 'RELISH',           'EYELASH', 'ATHLETE', 'ECONOMY', 'BUG', 'NOMAD', 'HIKER', 'MARINE', 'ARRANGE', 'JUDGE', 'IMPROVE', 'GRAVEL', 'COACH',         'CALENDAR', 'MATTRESS', 'GRADUATE', 'HEALTH'], ['EGYPT', 'ORCHID', 'COMPLETE', 'LEARN', 'DECLUTTER', 'GIRLFRIEND',            'PATIENT', 'SPIDER', 'FRAGRANCE', 'RING', 'TREADMILL', 'ANCESTRY', 'SCARF', 'FLOSS', 'PRACTICE', 'BUTCHER', 'REHAB',          'CANAL', 'LEG', 'OMELET', 'DOCTOR', 'COMPASS', 'MARKET', 'FATHER'], ['LUGGAGE', 'OCEAN', 'THIEF', 'BRICK', 'PLAN',            'ORGANIZE', 'HOOD', 'INFLATION', 'PROCRASTINATE', 'SHELF', 'SHELTER', 'CREATE', 'BENEFIT', 'SUBSIDIZE', 'STOVE', 'STOCK',     'GOAL', 'ROCKET', 'HOSPITAL', 'PERCH', 'ELBOW', 'EAGLE', 'CELLAR', 'CANCER'], ['BEAKER', 'PIMPLE', 'SUBWAY', 'WIFE',          'ROD', 'MOTIVATE', 'EXPLORE', 'TERMITE', 'SHOVEL', 'DISEASE', 'RESEARCH', 'DEBT', 'CARROT', 'DIVER', 'CLAM', 'INSURANCE',     'AWARD', 'DENTIST', 'REVIEW', 'VITAMIN', 'HONEYMOON', 'STATUE', 'SPARROW', 'RETIREMENT'], ['NETWORK', 'LOFT', 'BUILD',        'DRAWING', 'ANTLER', 'WINDOW', 'BOYFRIEND', 'TILE', 'CRITIC', 'CHOLESTEROL', 'SUCCEED', 'VACATION', 'TRAVEL', 'LEOPARD',      'ITEM', 'GARDEN', 'PROMOTION', 'PILATES', 'SAVINGS', 'SHOULDER', 'HAND', 'TRENCH', 'REWARD', 'GIFT']]

# %%
lists_2 = [['PALACE', 'BUGGY', 'MISSILE', 'JAPAN',          'MOTEL', 'DRAWING', 'LOFT', 'SHORTCAKE', 'GRAVEL', 'DIVER', 'LADY', 'PERFUME', 'SALAD', 'FILM', 'KIDNEY', 'BOUQUET',          'RIFLE', 'FIREPLACE', 'LABEL', 'MATTRESS', 'SISTER', 'CHEMIST', 'LAMP', 'WASP'], ['INFANT', 'PLIERS', 'LUGGAGE',              'BEAKER', 'AWARD', 'HERO', 'REPORT', 'KEEPER', 'GALLON', 'VIKING', 'DOLPHIN', 'ISLAND', 'CHEST', 'DUSTPAN', 'VENUS',          'TWISTER', 'NIGHTGOWN', 'MUSTARD', 'SPHINX', 'CURTAIN', 'NAPKIN', 'BLUEPRINT', 'ITEM', 'TRENCH'], ['BARLEY', 'SALMON',        'MASK', 'LACE', 'EMPIRE', 'EAGLE', 'PARTNER', 'COUCH', 'PIANO', 'BLENDER', 'GIFT', 'WAGON', 'LUNCH', 'TRUCK', 'PACKAGE',      'SHORTS', 'BRICK', 'GUITAR', 'RELISH', 'OMELET', 'DRIVER', 'CAMEL', 'BUG', 'FARMER'], ['PERCH', 'CRITIC', 'CROSS', 'LEG',     'TAXI', 'CLAMP', 'HANDBAG', 'RABBIT', 'POET', 'SNAKE', 'PIMPLE', 'STOVE', 'MARINE', 'BURGLAR', 'SURVEY', 'ANTLER',            'PIGEON', 'LOVER', 'XEROX', 'CAPTIVE', 'STUDENT', 'ORCHID', 'FEMALE', 'SILK'], ['FREEZER', 'TUNNEL', 'SHIRT', 'SHELTER',      'FOREST', 'TRACTOR', 'KETCHUP', 'SCARF', 'BLADE', 'ROBIN', 'WINDOW', 'HEDGE', 'COUSIN', 'CHAUFFEUR', 'SPOUSE', 'GYMNAST',     'QUARTER', 'TURTLE', 'TERMITE', 'FINGER', 'CREVICE', 'BUTCHER', 'EYELASH', 'SWAMP'], ['SCRIBBLE', 'HIKER', 'BRANDY',          'JUGGLER', 'KLEENEX', 'MAPLE', 'LUMBER', 'BLOUSE', 'MARKER', 'DRAGON', 'STAMP', 'IGLOO', 'RUG', 'NOMAD', 'HAND',              'WRENCH', 'STATUE', 'TYPIST', 'FLIPPER', 'POSTAGE', 'ROD', 'COMPASS', 'TEACHER', 'FOX'], ['SPARROW', 'POCKET', 'BADGE',       'LAGOON', 'WHISKERS', 'COBRA', 'ROCKET', 'SAUSAGE', 'NURSE', 'CANAL', 'SCALPEL', 'PRINCESS', 'BASEMENT', 'DASHBOARD',         'STOMACH', 'BISON', 'SPOOL', 'BEAST', 'ATOM', 'CRAYON', 'GRAVE', 'LAKE', 'COUNTRY', 'FOOT'], ['ICEBERG', 'MARKET',            'SHOULDER', 'LEOPARD', 'SHRUB', 'GHETTO', 'LONDON', 'WORLD', 'BANJO', 'VAGRANT', 'EXPERT', 'NEUTRON', 'PATIENT', 'ELBOW',     'SEAGULL', 'WAITER', 'RECORD', 'NOVEL', 'COWBOY', 'SHELF', 'GOBLIN', 'PECAN', 'JUDGE', 'CELLAR'], ['THIEF', 'EGYPT',          'COSTUME', 'CROWN', 'SHOVEL', 'SHERIFF', 'OUTDOORS', 'PATROL', 'LODGE', 'FRAGRANCE', 'TROUT', 'TRANSPLANT', 'BABY',           'HARP', 'OUTFIT', 'STAR', 'BUREAU', 'SEAL', 'VALVE', 'CATCHER', 'SWORD', 'CARROT', 'SUITCASE', 'LAVA'], ['PEPPER',            'SIBLING', 'SPIDER', 'PARSLEY', 'FRUIT', 'CYCLONE', 'PADDLE', 'CLAM', 'HEART', 'SUBWAY', 'PROTON', 'UMPIRE', 'SPOON',         'DIME', 'STONE', 'TILE', 'BRACES', 'ANKLE', 'WORKER', 'ACTRESS', 'CLIMBER', 'FLAG', 'HOOD', 'ZEBRA']]

# %%
lists_0 = [w for l in lists_0 for w in l]

# %%
lists_1 = [w for l in lists_1 for w in l]

# %%
lists_2 = [w for l in lists_2 for w in l]

# %%
print([len(l) for l in lists_0])
# Out:
# [24, 24, 24, 24, 24, 24, 24, 24, 24, 24]

# %%
print([len(l) for l in lists_1])
# Out:
# [24, 24, 24, 24, 24, 24, 24, 24, 24, 24]
